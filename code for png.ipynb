# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
from matplotlib.colors import colorConverter

# %%
pwd()
# Out:
# u'/Users/tt/\u0414\u0430\u043d\u043d\u044b\u0435 \u043f\u043e \u0434\u0438\u043f\u043b\u043e\u043c\u0443'

# %%
path = 'all precipitation from meteoRu/csv/'
moscow = '27612.csv'
# for filename in os.listdir(path):
#     res = []
#     for line in open(path+filename, 'r'):
#         item = line.rstrip()
#         v = [i for i in item.split(';')]
#         if len(v) == 14:
#             res.append(v)
#     data = pd.DataFrame(res)
#     data.to_csv(path1+ (filename.split('.'))[0]+'.csv', sep = ';', header=False, index=False, index_label=False)

data = pd.read_csv(path + moscow, sep = ';', header = None)
x = data[11]
plt.figure(figsize=(15,10))
# plt.legend('precipitation in Moscow', fontsize = 30)
plt.xlabel('номер дня в выборке'.decode('utf-8'), fontsize = 20)
plt.ylabel('количество осадков'.decode('utf-8'), fontsize = 20)
plt.title('Осадки в Москве'.decode('utf-8'),  fontsize=25)
plt.plot(x, 'red')


plt.savefig('../написание диплома/LaTeX/images/precipitation_Moscow.pdf')
plt.show()
plt.close()

# %%
len(x)
# Out:
# 24958

# %%
plt.figure(figsize=(15,10))
# plt.legend('precipitation in Moscow', fontsize = 30)
plt.xlabel('day number', fontsize = 20)
plt.ylabel('count of precipitation', fontsize = 20)
plt.title('precipitation in Moscow. last 10 years',  fontsize=25)
plt.plot(x[-3650:], 'red')


plt.savefig('../написание диплома/LaTeX/images/part_precipitation_Moscow.pdf')
plt.show()
plt.close()
