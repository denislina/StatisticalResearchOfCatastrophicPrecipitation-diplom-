# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
from matplotlib.colors import colorConverter
import os

# %%
#Data = pd.read_csv('all_parameters.csv', sep=';')
path_csv = './all precipitation from meteoRu/csv/'

# %%
from datetime import date, timedelta
d1 = date(1800, 1, 1)  # start date
d2 = date(2017, 5, 1)  # end date
delta = d2 - d1         # timedelta
dates = []
for i in range(delta.days + 1):
    dates.append(str(d1 + timedelta(days=i)))
L = len(dates)

# %%
df = pd.date_range('1/1/1800', periods=L)

# %%
col = [i.split('.')[0] for i in os.listdir(path_csv)]
stations = col
col[:5]
# Out:
# ['20046', '20069', '20087', '20107', '20289']

# %%
# Out:
#            20046 20069 20087 20107 20289 20292 20476 20667 20674 20744  ...   \
# 1900-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1900-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1901-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1902-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1902-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1902-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1902-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1902-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1902-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2014-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2015-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2016-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2017-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2017-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2017-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2017-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2017-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#            38750 38763 38836 38880 38895 38927 38933 38954 38974 38987
# 1900-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1900-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1901-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1902-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1902-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1902-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1902-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1902-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1902-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2014-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2015-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-06-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-07-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-08-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-09-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-10-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-11-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-12-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-02-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-03-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-04-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2017-05-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1409 rows x 600 columns]

# %%
filename = '20087.csv'
data = pd.read_csv(path_csv + filename, sep = ';', header = None)

# %%
import tqdm
from IPython.display import clear_output

# %%
df = pd.DataFrame( index=dates, columns=stations)
for filename in tqdm.tqdm(os.listdir(path_csv)):
    name = filename.split('.')[0]
    data = pd.read_csv(path_csv + filename, sep = ';', header = None)
    y = data[1]
    m = data[2]
    d = data[3]
    precipitation = data[11]
    #print name
    for i, value in enumerate(precipitation):
        try: 
            d1 = date(y[i], m[i], d[i])
            df.ix[str(d1),name] = value
        except:
            print name, y[i], m[i], d[i], value
        #print (str(d1))
    clear_output(True)
# Out:
# 100%|██████████| 600/600 [2:49:19<00:00,  6.83s/it]

# %% [raw]
# df.ix['1958-01-01', '20046']

# %% [raw]
# df.to_csv('all_precipitation.csv', sep = ';')

# %%
df = pd.read_csv('all_precipitation.csv', sep = ';', index_col=['Unnamed: 0'])

# %%
df.ix['1958-01-01', '20046']
df
# Out:
#             20046  20069  20087  20107  20289  20292  20476  20667  20674  \
# 1800-01-01    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-02    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-03    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-05    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-06    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-07    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-08    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-09    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-12    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-13    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-14    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-16    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-17    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-19    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-20    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-21    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-22    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-23    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-24    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-25    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-26    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-27    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-28    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-29    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-30    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2017-04-02    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-03    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-05    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-06    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-07    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-08    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-09    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-10    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-11    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-12    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-13    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-14    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-16    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-17    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-19    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-20    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-21    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-22    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-23    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-24    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-25    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-26    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-27    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-28    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-29    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-30    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-05-01    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#             20744  ...    38750  38763  38836  38880  38895  38927  38933  \
# 1800-01-01    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-02    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-03    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-04    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-05    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-06    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-07    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-08    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-09    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-10    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-11    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-12    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-13    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-14    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-15    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-16    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-17    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-18    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-19    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-20    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-21    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-22    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-23    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-24    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-25    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-26    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-27    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-28    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-29    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1800-01-30    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...           ...  ...      ...    ...    ...    ...    ...    ...    ...
# 2017-04-02    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-03    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-04    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-05    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-06    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-07    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-08    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-09    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-10    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-11    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-12    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-13    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-14    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-15    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-16    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-17    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-18    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-19    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-20    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-21    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-22    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-23    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-24    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-25    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-26    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-27    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-28    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-29    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-04-30    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-05-01    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#             38954  38974  38987
# 1800-01-01    NaN    NaN    NaN
# 1800-01-02    NaN    NaN    NaN
# 1800-01-03    NaN    NaN    NaN
# 1800-01-04    NaN    NaN    NaN
# 1800-01-05    NaN    NaN    NaN
# 1800-01-06    NaN    NaN    NaN
# 1800-01-07    NaN    NaN    NaN
# 1800-01-08    NaN    NaN    NaN
# 1800-01-09    NaN    NaN    NaN
# 1800-01-10    NaN    NaN    NaN
# 1800-01-11    NaN    NaN    NaN
# 1800-01-12    NaN    NaN    NaN
# 1800-01-13    NaN    NaN    NaN
# 1800-01-14    NaN    NaN    NaN
# 1800-01-15    NaN    NaN    NaN
# 1800-01-16    NaN    NaN    NaN
# 1800-01-17    NaN    NaN    NaN
# 1800-01-18    NaN    NaN    NaN
# 1800-01-19    NaN    NaN    NaN
# 1800-01-20    NaN    NaN    NaN
# 1800-01-21    NaN    NaN    NaN
# 1800-01-22    NaN    NaN    NaN
# 1800-01-23    NaN    NaN    NaN
# 1800-01-24    NaN    NaN    NaN
# 1800-01-25    NaN    NaN    NaN
# 1800-01-26    NaN    NaN    NaN
# 1800-01-27    NaN    NaN    NaN
# 1800-01-28    NaN    NaN    NaN
# 1800-01-29    NaN    NaN    NaN
# 1800-01-30    NaN    NaN    NaN
# ...           ...    ...    ...
# 2017-04-02    NaN    NaN    NaN
# 2017-04-03    NaN    NaN    NaN
# 2017-04-04    NaN    NaN    NaN
# 2017-04-05    NaN    NaN    NaN
# 2017-04-06    NaN    NaN    NaN
# 2017-04-07    NaN    NaN    NaN
# 2017-04-08    NaN    NaN    NaN
# 2017-04-09    NaN    NaN    NaN
# 2017-04-10    NaN    NaN    NaN
# 2017-04-11    NaN    NaN    NaN
# 2017-04-12    NaN    NaN    NaN
# 2017-04-13    NaN    NaN    NaN
# 2017-04-14    NaN    NaN    NaN
# 2017-04-15    NaN    NaN    NaN
# 2017-04-16    NaN    NaN    NaN
# 2017-04-17    NaN    NaN    NaN
# 2017-04-18    NaN    NaN    NaN
# 2017-04-19    NaN    NaN    NaN
# 2017-04-20    NaN    NaN    NaN
# 2017-04-21    NaN    NaN    NaN
# 2017-04-22    NaN    NaN    NaN
# 2017-04-23    NaN    NaN    NaN
# 2017-04-24    NaN    NaN    NaN
# 2017-04-25    NaN    NaN    NaN
# 2017-04-26    NaN    NaN    NaN
# 2017-04-27    NaN    NaN    NaN
# 2017-04-28    NaN    NaN    NaN
# 2017-04-29    NaN    NaN    NaN
# 2017-04-30    NaN    NaN    NaN
# 2017-05-01    NaN    NaN    NaN
#
# [79379 rows x 600 columns]

# %%
import math
math.isnan(df.ix['1900-01-01', '20046'])
#df.iloc number of str
sum(pd.isnull(df['20046']))*1./len(df['20046'])
# Out:
# 0.76865417805716874

# %%
df_crop = df.ix['1943-01-01':'2017-05-01']

# %% [raw]
# df_crop.to_csv('all_precipitation_crop.csv', sep = ';')

# %% [markdown]
# # таблица с результатами

# %%
import datetime
from dateutil.relativedelta import relativedelta

d1 = date(1900, 1, 1)  # start date
d2 = date(2017, 5, 1)  # end date

#today = datetime.date.today()
#current = datetime.date(2010, 8, 1)    
dates = []
while d1 <= d2:
    dates.append(d1)
    d1 += relativedelta(months=1)
every_m_d = [i.strftime("%Y-%m-%d") for i in dates]

# %%
df.ix['2015-05-01':'2015-05-04', stations[0]]
# Out:
# 2015-05-01    0.0
# 2015-05-02    0.0
# 2015-05-03    0.0
# 2015-05-04    0.0
# Name: 20046, dtype: float64

# %%
s = every_m_d[0]
y = int(s.split('-')[0]) + 1

d2 = date(2017, 5, 1) 
d2.strftime("%Y-%m-%d")
len(every_m_d)
# Out:
# 1409

# %%
import scipy.stats as ss
import scipy.optimize as so
def likelihood_f(P, x, neg=-1):
    n=np.round(P[0]) #by definition, it should be an integer 
    p=P[1]
    loc = 0
    return neg*(np.log(ss.nbinom.pmf(x, n, p, loc))).sum()

# %%
# %%time
annual_parameter_r_pr = pd.DataFrame( index=every_m_d, columns=stations)
annual_parameter_p_pr = pd.DataFrame( index=every_m_d, columns=stations)
annual_parameter_r_dr = pd.DataFrame( index=every_m_d, columns=stations)
annual_parameter_p_dr = pd.DataFrame( index=every_m_d, columns=stations)
delta = '10'
directory = './'+delta+'_years/'
if not os.path.exists(directory):
    os.makedirs(directory)
for st in stations:
# st = station[0]
# st = '27612'
    data = df[st]
    for date1 in tqdm.tqdm(every_m_d):
        #date1 = every_m_d[1300]
        dat = date1.split('-')
        y2 = int(dat[0]) + int(delta)
        m2 = int(dat[1])
        d2 = int(dat[2])
        date2 = date(y2, m2, d2).strftime("%Y-%m-%d")
        #print (date1, date2, st)
        X = df.ix[date1:date2, st]
        if len(X) > 0 and sum(X.notnull())*1./len(X) > 0.9:
            precipitation_without_nan = X.dropna()

            #precipitation
            length_of_precipitation = [];
            l = 0.;
            for i  in range(1, len(precipitation_without_nan)):
                if precipitation_without_nan[i] <= 0.0:
                    if l > 0:
                        length_of_precipitation.append(l - 1)
                    l = 0;
                else:
                    l += 1;

            r, p = 0.7, 0.3
            _ = so.minimize(likelihood_f, [r,p],args = (length_of_precipitation, -1), method='Nelder-Mead', options={'xtol': 1e-9})
            res_precipitation = _.fun
            r_precipitation, p_precipitation = _.x


            #dryperiods
            length_of_dry = [];
            l = 0.;
            for i  in range(1, len(precipitation_without_nan)):
                if precipitation_without_nan[i] > 0.0:
                    if l > 0:
                        length_of_dry.append(l - 1)
                    l = 0;
                else:
                    l += 1;

            r, p = 0.7, 0.3
            _ = so.minimize(likelihood_f, [r,p],args = (length_of_dry, -1), method='Nelder-Mead', options={'xtol': 1e-9})
            res_dry = _.fun
            r_dry, p_dry = _.x  
            annual_parameter_r_pr.ix[date1, st] = r_precipitation
            annual_parameter_p_pr.ix[date1, st] = p_precipitation
            annual_parameter_r_dr.ix[date1, st] = r_dry
            annual_parameter_p_dr.ix[date1, st] = p_dry
    #     else:
    #         annual_parameter_r_pr.ix[date1, st] = -1
    #         annual_parameter_p_pr.ix[date1, st] = -1
    #         annual_parameter_r_dr.ix[date1, st] = -1
    #         annual_parameter_p_dr.ix[date1, st] = -1

    a = [i for i in annual_parameter_r_pr[st]]
    b = [i for i in annual_parameter_p_pr[st]]
    c = [i for i in annual_parameter_r_dr[st]]
    d = [i for i in annual_parameter_p_dr[st]]
    # x_values = stations[:]

    # #Out[2]: <matplotlib.collections.PathCollection at 0x39686d0>

    # plt.xticks(x_values)
    plt.figure(figsize=(15,10))
    plt.plot(a, 'y.')
    plt.plot(b, 'g.')
    plt.plot(c, 'r.')
    plt.plot(d, 'b.')
    plt.xlabel('data',fontsize = 20)
    plt.ylabel('values',fontsize = 20)
    plt.legend(['r_pr', 'p_pr', 'r_dr', 'p_dr'], fontsize = 20)
    plt.savefig(directory + st + '_' delta + '_years_st' + '.png')
    
annual_parameter_p_dr.to_csv(directory+'annual_parameter_p_dr.csv', sep = ';')
annual_parameter_r_dr.to_csv(directory+'annual_parameter_r_dr.csv', sep = ';')
annual_parameter_p_pr.to_csv(directory+'annual_parameter_p_pr.csv', sep = ';')
annual_parameter_r_pr.to_csv(directory+'annual_parameter_r_pr.csv', sep = ';')
# Out:
# 100%|██████████| 1409/1409 [03:36<00:00,  6.50it/s]
# CPU times: user 3min 34s, sys: 5.56 s, total: 3min 39s
# Wall time: 3min 37s

# %% [raw]
# a[1300], b[1300], c[1300], d[1300]

# %%
len(a)
# Out:
# 1409

# %%
a = [i for i in annual_parameter_r_pr[st]]
b = [i for i in annual_parameter_p_pr[st]]
c = [i for i in annual_parameter_r_dr[st]]
d = [i for i in annual_parameter_p_dr[st]]
# x_values = stations[:]

# #Out[2]: <matplotlib.collections.PathCollection at 0x39686d0>

# plt.xticks(x_values)
plt.figure(figsize=(15,10))
plt.plot(a, 'y.')
plt.plot(b, 'g.')
plt.plot(c, 'r.')
plt.plot(d, 'b.')
plt.xlabel('data',fontsize = 20)
plt.ylabel('values',fontsize = 20)
plt.legend(['r_pr', 'p_pr', 'r_dr', 'p_dr'], fontsize = 20)
plt.savefig(delta + '_years_st_'+ st + '.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-256-c29035e4f425> in <module>()
#      18 plt.legend(['r_pr', 'p_pr', 'r_dr', 'p_dr'], fontsize = 20)
#      19 plt.savefig(delta + '_years_st_'+ st + '.png')
# ---> 20 plt.show()
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     162             publish_display_data(data=obj, metadata=metadata)
#     163         else:
# --> 164             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     165             if not format_dict:
#     166                 # nothing to display (e.g. _ipython_display_ took over)
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     143             md = None
#     144             try:
# --> 145                 data = formatter(obj)
#     146             except:
#     147                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/formatters.pyc in catch_format_error(method, self, *args, **kwargs)
#     188     """show traceback on failed format call"""
#     189     try:
# --> 190         r = method(self, *args, **kwargs)
#     191     except NotImplementedError:
#     192         # don't warn on NotImplementedErrors
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2242                 orientation=orientation,
#    2243                 bbox_inches_restore=_bbox_inches_restore,
# -> 2244                 **kwargs)
#    2245         finally:
#    2246             if bbox_inches and restore_bbox:
#
# /Users/tt/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     554
#     555         try:
# --> 556             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     557         finally:
#     558             if close:
#
# KeyboardInterrupt:

# %%
str(delta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-229-a2a11e0999b8> in <module>()
# ----> 1 str(delta)
#
# TypeError: 'Index' object is not callable

# %%
print str(delta)+'_year_' + str(st) + '.png'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-225-15a668eb0a41> in <module>()
# ----> 1 print str(delta)+'_year_' + str(st) + '.png'
#
# TypeError: 'Index' object is not callable

# %%
plt.hist(length_of_precipitation)
plt.show()

# %%
df.ix['2015-05-01':'2015-05-10', stations[0]]
# Out:
# 2015-05-01    0.0
# 2015-05-02    0.0
# 2015-05-03    0.0
# 2015-05-04    0.0
# 2015-05-05    0.0
# 2015-05-06    0.7
# 2015-05-07    1.2
# 2015-05-08    9.2
# 2015-05-09    0.0
# 2015-05-10    0.0
# Name: 20046, dtype: float64
